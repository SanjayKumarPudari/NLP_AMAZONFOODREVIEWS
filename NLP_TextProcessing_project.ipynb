# %% [markdown]
# <div style="background-color:#2E87A4 ;color:#FDFDFD;padding:20px;border:1px solid #3184BB;text-align:center;">
# <p><font size="14" color="#FDFDFD" face="Lora"><i>Text Data - Sentiment Analysis</i></font> </p>
# </div>

# %% [markdown]
# ## Data Description
#  This dataset consists of reviews of fine foods from amazon. The data span a period of more than 10 years, including all ~500,000 reviews up to October 2012. Reviews include product and user information, ratings, and a plain text review. It also includes reviews from all other Amazon categories.
# ## Data includes:
# - Reviews from Oct 1999 - Oct 2012 - 568,454 reviews
# - 256,059 Users and 74,258 products
# - 260 users with > 50 reviews

# %% [markdown]
# # Problem Statement :
#  #### The aim here will be to `predict the score for the given text review` by an individual for the product he brought on amazon.

# %% [markdown]
# ## Create DataFrame from raw text files

# %%
import pandas as pd
import numpy as np

import re
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
plt.style.use('bmh')

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# for HD visualizations
# %config InlineBackend.figure_format='retina'

# %%
# !unzip '/content/drive/MyDrive/txt_reviews.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: txt_reviews/review_95499.txt
#   inflating: txt_reviews/review_955.txt
#   inflating: txt_reviews/review_9550.txt
#   inflating: txt_reviews/review_95500.txt
#   inflating: txt_reviews/review_95501.txt
#   inflating: txt_reviews/review_95502.txt
#   inflating: txt_reviews/review_95503.txt
#   inflating: txt_reviews/review_95504.txt
#   inflating: txt_reviews/review_95505.txt
#   inflating: txt_reviews/review_95506.txt
#   inflating: txt_reviews/review_95507.txt
#   inflating: txt_reviews/review_95508.txt
#   inflating: txt_reviews/review_95509.txt
#   inflating: txt_reviews/review_9551.txt
#   inflating: txt_reviews/review_95510.txt
#   inflating: txt_reviews/review_95511.txt
#   inflating: txt_reviews/review_95512.txt
#   inflating: txt_reviews/review_95513.txt
#   inflating: txt_reviews/review_95514.txt
#   inflating: txt_reviews/review_95515.txt
#   inflating: txt_reviews/review_95516.txt
#   inflating: txt_reviews/review_95517.txt
#   inflating: txt_reviews/review_95518.txt
#   inflating: txt_reviews/review_95519.txt
#   inflating: txt_reviews/review_9552.txt
#   inflating: txt_reviews/review_95520.txt
#   inflating: txt_reviews/review_95521.txt
#   inflating: txt_reviews/review_95522.txt
#   inflating: txt_reviews/review_95523.txt
#   inflating: txt_reviews/review_95524.txt
#   inflating: txt_reviews/review_95525.txt
#   inflating: txt_reviews/review_95526.txt
#   inflating: txt_reviews/review_95527.txt
#   inflating: txt_reviews/review_95528.txt
#   inflating: txt_reviews/review_95529.txt
#   inflating: txt_reviews/review_9553.txt
#   inflating: txt_reviews/review_95530.txt
#   inflating: txt_reviews/review_95531.txt
#   inflating: txt_reviews/review_95532.txt
#   inflating: txt_reviews/review_95533.txt
#   inflating: txt_reviews/review_95534.txt
#   inflating: txt_reviews/review_95535.txt
#   inflating: txt_reviews/review_95536.txt
#   inflating: txt_reviews/review_95537.txt
#   inflating: txt_reviews/review_95538.txt
#   inflating: txt_reviews/review_95539.txt
#   inflating: txt_reviews/review_9554.txt
#   inflating: txt_reviews/review_95540.txt
#   inflating: txt_reviews/review_95541.txt
#   inflating: txt_reviews/review_95542.txt
#   inflating: txt_reviews/review_99984.txt
#   inflating: txt_reviews/review_99985.txt
#   inflating: txt_reviews/review_99986.txt
#   inflating: txt_reviews/review_99987.txt
#   inflating: txt_reviews/review_99988.txt
#   inflating: txt_reviews/review_99989.txt
#   inflating: txt_reviews/review_9999.txt
#   inflating: txt_reviews/review_99990.txt
#   inflating: txt_reviews/review_99991.txt
#   inflating: txt_reviews/review_99992.txt
#   inflating: txt_reviews/review_99993.txt
#   inflating: txt_reviews/review_99994.txt
#   inflating: txt_reviews/review_99995.txt
#   inflating: txt_reviews/review_99996.txt
#   inflating: txt_reviews/review_99997.txt
#   inflating: txt_reviews/review_99998.txt
#   inflating: txt_reviews/review_99999.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.getcwd()
# Out:
# '/content'

# %%
filename=os.listdir('/content/txt_reviews')

# %%
print(len(filename))
# Out:
# 568454

# %%
Product_id=[]
User_id=[]
Profile_Name=[]
Helpfulness_Numerator=[]
Helpfulness_Denominator=[]
Score=[]
Time=[]
Review_Summary=[]
Review_Text=[]


for review in filename:
    with open(('/content/txt_reviews/'+review),'r') as f:
        lines = f.readlines()
        Product_id.append(lines[0].split(":")[1].strip('\n'))
        User_id.append(lines[1].split(":")[1].strip('\n'))
        Profile_Name.append(lines[2].split(":")[1].strip('\n'))
        Helpfulness_Numerator.append(lines[3].split(":")[1].strip('\n'))
        Helpfulness_Denominator.append(lines[4].split(":")[1].strip('\n'))
        Score.append(lines[5].split(":")[1].strip('\n'))
        Time.append(lines[6].split(":")[1].strip('\n'))
        Review_Summary.append(lines[7].split(":")[1].strip('\n'))
        Review_Text.append(lines[8].split(":")[1].strip('\n'))



nlp_df=pd.DataFrame({"Product_id":Product_id,"User_id":User_id,"Profile_Name":Profile_Name,"Helpfulness_Numerator":Helpfulness_Numerator,"Helpfulness_Denominator":Helpfulness_Denominator,
                   "Score":Score,"Time":Time,"Review_Summary":Review_Summary,"Review_Text":Review_Text})

# %% [markdown]
# ### Load the data and perform the basic EDA to understand the data.

# %%
nlp_df
# Out:
#          Product_id          User_id              Profile_Name  \
# 0        B000UU8KA2   A3PTDVALS7JJGA                   vicop69
# 1        B0002DGRRA   A38AN6ZRMHV6EU         Carole S. Stabile
# 2        B008JHZ150   A1F7YU6O5RU432            Angela Streiff
# 3        B000EH4XZM    AQ1G6JEBH5QWY     Ms. Diane C. Frandsen
# 4        B00024D9X4   A1P85GZIZSL9IE   Julia Osborn "texasmom"
# ...             ...              ...                       ...
# 568449   B002CIP8OQ   A25GSFMKH8B52D              steven malia
# 568450   B0026RQTGE   A2WUK1O9802GNW               Ichiro "IT"
# 568451   B000F9XBDE   A13C90XAUL1K81    Elle M. "Literary Mom"
# 568452   B0032CJPOK   A3OQ40N5PAFIBQ               Mrs. Deming
# 568453   B0046HLZ9S    AR7Q245YM2EES                 sternhift
#
#        Helpfulness_Numerator Helpfulness_Denominator Score         Time  \
# 0                          0                       0     5   1318896000
# 1                          0                       0     5   1243382400
# 2                          1                       1     5   1347580800
# 3                          0                       0     4   1224806400
# 4                          1                       1     1   1301097600
# ...                      ...                     ...   ...          ...
# 568449                     1                       1     5   1335657600
# 568450                     0                       0     5   1341273600
# 568451                     4                       4     5   1206316800
# 568452                     1                       1     1   1349222400
# 568453                     0                       0     1   1350432000
#
#                                  Review_Summary  \
# 0                                  Rain-Blo Gum
# 1                                     Happy Dog
# 2        A delicious hot sauce with some flavor
# 3                                   rice review
# 4                                          Yuk!
# ...                                         ...
# 568449                              irish seeds
# 568450                 My dog's favorite treat!
# 568451                                    Yummy
# 568452                         Made My Son Sick
# 568453                         don't buy these!
#
#                                               Review_Text
# 0        This is the best gum ever. They make smaller ...
# 1        This is a healthy and good snack for my dog. ...
# 2        I love that this Tabanero hot sauce actually ...
# 3        love this product. very good quality. The fla...
# 4        This is by far the nastiest thing I have ever...
# ...                                                   ...
# 568449   very good product still growing for me i purc...
# 568450   Greenies are great dental chews that keep my ...
# 568451   I wasn't expecting much, having found a box o...
# 568452   I started my 3 month old son (who is partiall...
# 568453   I was curious about these, and so I bought th...
#
# [568454 rows x 9 columns]

# %%
# Converting DataFrame to CSV formate

# %%
nlp_df.to_csv('/content/txt_reviews.csv')

# %%
# Loading the converted DataFrame

# %%
nlp_df1=pd.read_csv(r"/content/txt_reviews.csv")

# %% [markdown]
# ## Performing a basic Exploratory Data Analysis to understand the data

# %%
nlp_df1.head()
# Out:
#    Unnamed: 0   Product_id          User_id              Profile_Name  \
# 0           0   B000UU8KA2   A3PTDVALS7JJGA                   vicop69
# 1           1   B0002DGRRA   A38AN6ZRMHV6EU         Carole S. Stabile
# 2           2   B008JHZ150   A1F7YU6O5RU432            Angela Streiff
# 3           3   B000EH4XZM    AQ1G6JEBH5QWY     Ms. Diane C. Frandsen
# 4           4   B00024D9X4   A1P85GZIZSL9IE   Julia Osborn "texasmom"
#
#    Helpfulness_Numerator  Helpfulness_Denominator  Score        Time  \
# 0                      0                        0      5  1318896000
# 1                      0                        0      5  1243382400
# 2                      1                        1      5  1347580800
# 3                      0                        0      4  1224806400
# 4                      1                        1      1  1301097600
#
#                             Review_Summary  \
# 0                             Rain-Blo Gum
# 1                                Happy Dog
# 2   A delicious hot sauce with some flavor
# 3                              rice review
# 4                                     Yuk!
#
#                                          Review_Text
# 0   This is the best gum ever. They make smaller ...
# 1   This is a healthy and good snack for my dog. ...
# 2   I love that this Tabanero hot sauce actually ...
# 3   love this product. very good quality. The fla...
# 4   This is by far the nastiest thing I have ever...

# %%
nlp_df1.tail()
# Out:
#         Unnamed: 0   Product_id          User_id             Profile_Name  \
# 568449      568449   B002CIP8OQ   A25GSFMKH8B52D             steven malia
# 568450      568450   B0026RQTGE   A2WUK1O9802GNW              Ichiro "IT"
# 568451      568451   B000F9XBDE   A13C90XAUL1K81   Elle M. "Literary Mom"
# 568452      568452   B0032CJPOK   A3OQ40N5PAFIBQ              Mrs. Deming
# 568453      568453   B0046HLZ9S    AR7Q245YM2EES                sternhift
#
#         Helpfulness_Numerator  Helpfulness_Denominator  Score        Time  \
# 568449                      1                        1      5  1335657600
# 568450                      0                        0      5  1341273600
# 568451                      4                        4      5  1206316800
# 568452                      1                        1      1  1349222400
# 568453                      0                        0      1  1350432000
#
#                    Review_Summary  \
# 568449                irish seeds
# 568450   My dog's favorite treat!
# 568451                      Yummy
# 568452           Made My Son Sick
# 568453           don't buy these!
#
#                                               Review_Text
# 568449   very good product still growing for me i purc...
# 568450   Greenies are great dental chews that keep my ...
# 568451   I wasn't expecting much, having found a box o...
# 568452   I started my 3 month old son (who is partiall...
# 568453   I was curious about these, and so I bought th...

# %%
# check for any corrupted data by `df.info()` check weahther all the features are having the correct data type

# %%
nlp_df1.info() # the data types of all the features are correct but we are haing unwanted characters which will be removed during cleaning #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               568454 non-null  int64
#  1   Product_id               568454 non-null  object
#  2   User_id                  568454 non-null  object
#  3   Profile_Name             568454 non-null  object
#  4   Helpfulness_Numerator    568454 non-null  int64
#  5   Helpfulness_Denominator  568454 non-null  int64
#  6   Score                    568454 non-null  int64
#  7   Time                     568454 non-null  int64
#  8   Review_Summary           568454 non-null  object
#  9   Review_Text              568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
# Check for Duplicates in our dataset

# %%
nlp_df1.duplicated().value_counts() # As we can see that there are no duplicated records in our dataset
# Out:
# False    568454
# dtype: int64

# %%
# Check for missing values

# %%
nlp_df1.isna().sum() # As we can see that there are no missing the values in our dataset
# Out:
# Unnamed: 0                 0
# Product_id                 0
# User_id                    0
# Profile_Name               0
# Helpfulness_Numerator      0
# Helpfulness_Denominator    0
# Score                      0
# Time                       0
# Review_Summary             0
# Review_Text                0
# dtype: int64

# %% [markdown]
# ## Check for Outliers

# %% [markdown]
# ### Skewness:
# **Skewness refers to a distortion or asymmetry that deviates from the symmetrical bell curve, or normal distribution, in a set of data. If the curve is shifted to the left or to the right, it is said to be skewed.**
#
#
# * Less than -1 or greater than 1, then the distribution is highly skewed.
# * Between -1 and -0.5 or 0.5 and 1, then the distribution is moderately skewed.
# * Between -0.5 and 0.5, then the distribution is approx. symmetric.
# * When skewness = 0, then the data is perfrctly symmetric.

# %%
nlp_df1.columns # to view the columns
# Out:
# Index(['Unnamed: 0', 'Product_id', 'User_id', 'Profile_Name',
#        'Helpfulness_Numerator', 'Helpfulness_Denominator', 'Score', 'Time',
#        'Review_Summary', 'Review_Text'],
#       dtype='object')

# %%
nlp_df1.drop(['Unnamed: 0'] , axis = 1, inplace = True)
nlp_df1 # Unwanted column is droped
# Out:
#          Product_id          User_id              Profile_Name  \
# 0        B000UU8KA2   A3PTDVALS7JJGA                   vicop69
# 1        B0002DGRRA   A38AN6ZRMHV6EU         Carole S. Stabile
# 2        B008JHZ150   A1F7YU6O5RU432            Angela Streiff
# 3        B000EH4XZM    AQ1G6JEBH5QWY     Ms. Diane C. Frandsen
# 4        B00024D9X4   A1P85GZIZSL9IE   Julia Osborn "texasmom"
# ...             ...              ...                       ...
# 568449   B002CIP8OQ   A25GSFMKH8B52D              steven malia
# 568450   B0026RQTGE   A2WUK1O9802GNW               Ichiro "IT"
# 568451   B000F9XBDE   A13C90XAUL1K81    Elle M. "Literary Mom"
# 568452   B0032CJPOK   A3OQ40N5PAFIBQ               Mrs. Deming
# 568453   B0046HLZ9S    AR7Q245YM2EES                 sternhift
#
#         Helpfulness_Numerator  Helpfulness_Denominator  Score        Time  \
# 0                           0                        0      5  1318896000
# 1                           0                        0      5  1243382400
# 2                           1                        1      5  1347580800
# 3                           0                        0      4  1224806400
# 4                           1                        1      1  1301097600
# ...                       ...                      ...    ...         ...
# 568449                      1                        1      5  1335657600
# 568450                      0                        0      5  1341273600
# 568451                      4                        4      5  1206316800
# 568452                      1                        1      1  1349222400
# 568453                      0                        0      1  1350432000
#
#                                  Review_Summary  \
# 0                                  Rain-Blo Gum
# 1                                     Happy Dog
# 2        A delicious hot sauce with some flavor
# 3                                   rice review
# 4                                          Yuk!
# ...                                         ...
# 568449                              irish seeds
# 568450                 My dog's favorite treat!
# 568451                                    Yummy
# 568452                         Made My Son Sick
# 568453                         don't buy these!
#
#                                               Review_Text
# 0        This is the best gum ever. They make smaller ...
# 1        This is a healthy and good snack for my dog. ...
# 2        I love that this Tabanero hot sauce actually ...
# 3        love this product. very good quality. The fla...
# 4        This is by far the nastiest thing I have ever...
# ...                                                   ...
# 568449   very good product still growing for me i purc...
# 568450   Greenies are great dental chews that keep my ...
# 568451   I wasn't expecting much, having found a box o...
# 568452   I started my 3 month old son (who is partiall...
# 568453   I was curious about these, and so I bought th...
#
# [568454 rows x 9 columns]

# %%
nlp_df1.skew() # check for the Skewness to see if there are any presence of outliers:
# Out:
# Helpfulness_Numerator      37.521614
# Helpfulness_Denominator    32.632886
# Score                      -1.460985
# Time                       -1.228063
# dtype: float64

# %% [markdown]
# #### Intuitions:
#
# * As we can see that features `Helpfulness_Numerator, Helpfulness_Denominator`
#   is having a skewness of far greater than one and
# * Hence the distribution is highly `skewed` ( Mean is far away from Median) and `outliers` are present.
# * the features `Score,Time` having skewness slightly less than -1. Hence they are also having the outliers.

# %%
# View the outliers through visualization
# Drawing the boxplot
plt.figure(figsize=(5,8), dpi = 150)
plt.subplot(221)
sns.boxplot(x= 'Helpfulness_Numerator', data=nlp_df1);
plt.subplot(222)
sns.boxplot(x= 'Helpfulness_Denominator', data=nlp_df1);
plt.subplot(223)
sns.boxplot(x= 'Score', data=nlp_df1);
plt.subplot(224)
sns.boxplot(x= 'Time', data=nlp_df1);

# %% [markdown]
# ## Note
# For the given `Text Data - Sentiment Analysis` we only require **Review_Text** and **Score** for the `Model Building` which will predict the score for the given text review

# %% [markdown]
# # Build a model
#
# ### Task A - Perform data preprocessing on the given text data and convert it into numerical vectors.

# %%
nlp = nlp_df1[['Review_Text','Score']]

# %%
nlp.head()
# Out:
#                                          Review_Text  Score
# 0   This is the best gum ever. They make smaller ...      5
# 1   This is a healthy and good snack for my dog. ...      5
# 2   I love that this Tabanero hot sauce actually ...      5
# 3   love this product. very good quality. The fla...      4
# 4   This is by far the nastiest thing I have ever...      1

# %%
y = nlp['Score']
X = nlp[['Review_Text']]

# %%
# Splitting into train and test

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=27)

# %%
X_train.head()
# Out:
#                                               Review_Text
# 67866    Our dog loves this food. We tried the salmon ...
# 122434   I was so sick of making gummy pasty rice with...
# 553789                                               Note
# 356935   I like many of Enjoy Life's products, but not...
# 351597   The product is one I have been using for year...

# %%
X_train.shape
# Out:
# (397917, 1)

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
## initialise the inbuilt Stemmer
stemmer = PorterStemmer()

# %%
## We can also use Lemmatizer instead of Stemmer
lemmatizer = WordNetLemmatizer()

# %%
def pre_Processor(Raw_text, flag):
    # Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", Raw_text)
    
    # change sentence to lower case
    sentence = sentence.lower()

    # tokenize into words
    tokens = sentence.split()
    
    # remove stop words                
    clean_tokens = [t for t in tokens if not t in stopwords.words("english")]
    
    # Stemming/Lemmatization
    if(flag == 'stem'):
        clean_tokens = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens), len(clean_tokens)])

# %%
# # Convert to series
temp =X_train['Review_Text'].apply(lambda x: pre_Processor(x, 'stem'))

# %%
temp.head()
# Out:
#                                                         0   1
# 67866   dog love food tri salmon whitefish flavor also...  39
# 122434  sick make gummi pasti rice bland flavor rice a...  28
# 553789                                               note   1
# 356935  like mani enjoy life product one tast best des...  37
# 351597  product one use year difficult find store boug...  11

# %%
temp.columns = ['clean_Reviewtext_stem', 'Reviewtext_length_stem']

temp.head()
# Out:
#                                     clean_Reviewtext_stem  \
# 67866   dog love food tri salmon whitefish flavor also...
# 122434  sick make gummi pasti rice bland flavor rice a...
# 553789                                               note
# 356935  like mani enjoy life product one tast best des...
# 351597  product one use year difficult find store boug...
#
#         Reviewtext_length_stem
# 67866                       39
# 122434                      28
# 553789                       1
# 356935                      37
# 351597                      11

# %%
X_test.head()
# Out:
#                                               Review_Text
# 438256   I received the cereal fast and even came with...
# 362810   I really enjoy these to fill my belly a bit w...
# 33030    When it comes to soft, edible candy it's hard...
# 486713   My daughter loves these "Pop-Tarts".  She oft...
# 39460    I use this to make a batch of our favorite ic...

# %%
from tqdm import tqdm, tqdm_notebook

# %%
# Register `pandas.progress_apply` and `pandas.Series.map_apply` with `tqdm`

tqdm.pandas()

# %%
temp1 = X_test['Review_Text'].progress_apply(lambda x: pre_Processor(x, 'stem'))

temp1.head()
# Out:
# 100%|██████████| 170537/170537 [34:51<00:00, 81.55it/s]
#                                                         0   1
# 438256  receiv cereal fast even came coupon next purch...  12
# 362810  realli enjoy fill belli bit without indulg jun...  42
# 33030   come soft edibl candi hard separ packag treat ...  68
# 486713  daughter love pop tart often eat morn yogurt s...  24
# 39460   use make batch favorit ice cream use packag va...  29

# %%
temp1.columns = ['clean_Reviewtext_stem', 'Reviewtext_length_stem']

temp1.head()
# Out:
#                                     clean_Reviewtext_stem  \
# 438256  receiv cereal fast even came coupon next purch...
# 362810  realli enjoy fill belli bit without indulg jun...
# 33030   come soft edibl candi hard separ packag treat ...
# 486713  daughter love pop tart often eat morn yogurt s...
# 39460   use make batch favorit ice cream use packag va...
#
#         Reviewtext_length_stem
# 438256                      12
# 362810                      42
# 33030                       68
# 486713                      24
# 39460                       29

# %%
X_train = pd.concat([X_train, temp], axis=1)

X_train.head()
# Out:
#                                               Review_Text  \
# 67866    Our dog loves this food. We tried the salmon ...
# 122434   I was so sick of making gummy pasty rice with...
# 553789                                               Note
# 356935   I like many of Enjoy Life's products, but not...
# 351597   The product is one I have been using for year...
#
#                                     clean_Reviewtext_stem  \
# 67866   dog love food tri salmon whitefish flavor also...
# 122434  sick make gummi pasti rice bland flavor rice a...
# 553789                                               note
# 356935  like mani enjoy life product one tast best des...
# 351597  product one use year difficult find store boug...
#
#         Reviewtext_length_stem
# 67866                       39
# 122434                      28
# 553789                       1
# 356935                      37
# 351597                      11

# %%
X_test = pd.concat([X_test, temp1], axis=1)

X_test.head()
# Out:
#                                               Review_Text  \
# 438256   I received the cereal fast and even came with...
# 362810   I really enjoy these to fill my belly a bit w...
# 33030    When it comes to soft, edible candy it's hard...
# 486713   My daughter loves these "Pop-Tarts".  She oft...
# 39460    I use this to make a batch of our favorite ic...
#
#                                     clean_Reviewtext_stem  \
# 438256  receiv cereal fast even came coupon next purch...
# 362810  realli enjoy fill belli bit without indulg jun...
# 33030   come soft edibl candi hard separ packag treat ...
# 486713  daughter love pop tart often eat morn yogurt s...
# 39460   use make batch favorit ice cream use packag va...
#
#         Reviewtext_length_stem
# 438256                      12
# 362810                      42
# 33030                       68
# 486713                      24
# 39460                       29

# %% [markdown]
# ## Converting Text to Numerical vectors - BOW Representation

# %%
X_train.head()
# Out:
#                                               Review_Text  \
# 67866    Our dog loves this food. We tried the salmon ...
# 122434   I was so sick of making gummy pasty rice with...
# 553789                                               Note
# 356935   I like many of Enjoy Life's products, but not...
# 351597   The product is one I have been using for year...
#
#                                     clean_Reviewtext_stem  \
# 67866   dog love food tri salmon whitefish flavor also...
# 122434  sick make gummi pasti rice bland flavor rice a...
# 553789                                               note
# 356935  like mani enjoy life product one tast best des...
# 351597  product one use year difficult find store boug...
#
#         Reviewtext_length_stem
# 67866                       39
# 122434                      28
# 553789                       1
# 356935                      37
# 351597                      11

# %%
from sklearn.feature_extraction.text import CountVectorizer

vocab = CountVectorizer()

X_train_bow = vocab.fit_transform(X_train['clean_Reviewtext_stem'])

# %%
X_train_bow
# Out:
# <397917x60348 sparse matrix of type '<class 'numpy.int64'>'
# 	with 11680113 stored elements in Compressed Sparse Row format>

# %%
print("Total unique words:", len(vocab.vocabulary_))

print("Type of train features:", type(X_train_bow))

print("Shape of input data:", X_train_bow.shape)
# Out:
# Total unique words: 60348
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (397917, 60348)

# %%
X_test_bow = vocab.transform(X_test['clean_Reviewtext_stem'])

# %%
X_test_bow
# Out:
# <170537x60348 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5002697 stored elements in Compressed Sparse Row format>

# %%
print("Total unique words:", len(vocab.vocabulary_))

print("Type of train features:", type(X_test_bow))

print("Shape of input data:", X_test_bow.shape)
# Out:
# Total unique words: 60348
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (170537, 60348)

# %% [markdown]
# # Task B - Build models to predict the Score of a given text review.

# %% [markdown]
# ## Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
classifier1 = LogisticRegression()
classifier1.fit(X_train_bow, y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred = classifier1.predict(X_test_bow) # Prediction

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred)) # Evaluating the model using the Evaluation metrics

print(classification_report(y_test, y_test_pred))
# Out:
# 0.7285515753179662
#               precision    recall  f1-score   support
#
#            1       0.66      0.64      0.65     15776
#            2       0.43      0.22      0.29      8959
#            3       0.44      0.28      0.34     12684
#            4       0.50      0.23      0.31     23994
#            5       0.78      0.95      0.86    109124
#
#     accuracy                           0.73    170537
#    macro avg       0.56      0.46      0.49    170537
# weighted avg       0.69      0.73      0.69    170537

# %%
LR_ac = accuracy_score(y_test, y_test_pred)

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred, color='red', alpha=0.5);

# %% [markdown]
# ## Decision Tree Classifier Model

# %%
from sklearn.tree import DecisionTreeClassifier
classifier2 = DecisionTreeClassifier()
classifier2.fit(X_train_bow, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred1 = classifier2.predict(X_test_bow) # Prediction

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred1)) # Evaluating the model using the Evaluation metrics

print(classification_report(y_test, y_test_pred1))
# Out:
# 0.7446126060620276
#               precision    recall  f1-score   support
#
#            1       0.63      0.61      0.62     15776
#            2       0.50      0.44      0.47      8959
#            3       0.52      0.47      0.49     12684
#            4       0.54      0.50      0.52     23994
#            5       0.84      0.87      0.86    109124
#
#     accuracy                           0.74    170537
#    macro avg       0.61      0.58      0.59    170537
# weighted avg       0.74      0.74      0.74    170537

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred1, color='red', alpha=0.5);

# %%
DT_ac = accuracy_score(y_test, y_test_pred1)

# %% [markdown]
# ## KNeighborsClassifier Model

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier4 = KNeighborsClassifier()
classifier4.fit(X_train_bow, y_train) # Training the model and Building the model
# Out:
# KNeighborsClassifier()

# %%
y_test_pred3 = classifier4.predict(X_test_bow) # Prediction

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred3)) # Evaluating the model using the Evaluation metrics

print(classification_report(y_test, y_test_pred3))
# Out:
# 0.6622316564733752
#               precision    recall  f1-score   support
#
#            1       0.52      0.40      0.45     15776
#            2       0.41      0.31      0.36      8959
#            3       0.44      0.32      0.37     12684
#            4       0.38      0.38      0.38     23994
#            5       0.77      0.83      0.80    109124
#
#     accuracy                           0.66    170537
#    macro avg       0.50      0.45      0.47    170537
# weighted avg       0.65      0.66      0.65    170537

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred3, color='red', alpha=0.5);

# %%
KN_ac = accuracy_score(y_test, y_test_pred3)

# %% [markdown]
# ## Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier3 = RandomForestClassifier()
classifier3.fit(X_train_bow, y_train)
# Out:
# RandomForestClassifier()

# %%
y_test_pred2 = classifier3.predict(X_test_bow) # Prediction

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred2)) # Evaluating the model using the Evaluation metrics

print(classification_report(y_test, y_test_pred2))
# Out:
# 0.7921624046394624
#               precision    recall  f1-score   support
#
#            1       0.91      0.55      0.68     15776
#            2       0.98      0.38      0.55      8959
#            3       0.97      0.39      0.55     12684
#            4       0.96      0.39      0.55     23994
#            5       0.76      1.00      0.86    109124
#
#     accuracy                           0.79    170537
#    macro avg       0.91      0.54      0.64    170537
# weighted avg       0.83      0.79      0.76    170537

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred2, color='red', alpha=0.5);

# %%
RF_ac = accuracy_score(y_test, y_test_pred2)

# %% [markdown]
# ## GradientBoostingClassifier Model

# %%
from sklearn.ensemble import GradientBoostingClassifier
clasifier5 = GradientBoostingClassifier()
clasifier5.fit(X_train_bow, y_train) # Training the model and Building the model
# Out:
# GradientBoostingClassifier()

# %%
y_test_pred5= clasifier5.predict(X_test_bow) # Prediction

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred5)) # Evaluating the model using the Evaluation metrics

print(classification_report(y_test, y_test_pred5))
# Out:
# 0.6800928830693632
#               precision    recall  f1-score   support
#
#            1       0.71      0.28      0.40     15776
#            2       0.52      0.05      0.08      8959
#            3       0.50      0.08      0.14     12684
#            4       0.51      0.11      0.18     23994
#            5       0.69      0.99      0.81    109124
#
#     accuracy                           0.68    170537
#    macro avg       0.59      0.30      0.32    170537
# weighted avg       0.64      0.68      0.60    170537

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred5, color='red', alpha=0.5);

# %%
GBDT_ac = accuracy_score(y_test, y_test_pred5)

# %%
dict1 = {'Model':['LogisticRegression','KNeighborsClassifier','DecisionTreeClassifier','RandomForestClassifier','GradientBoostingClassifier'],
                       'accuracy_score':[LR_ac,KN_ac,DT_ac,RF_ac,GBDT_ac]}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#                         Model  accuracy_score
# 0          LogisticRegression        0.728552
# 1        KNeighborsClassifier        0.662232
# 2      DecisionTreeClassifier        0.744613
# 3      RandomForestClassifier        0.792162
# 4  GradientBoostingClassifier        0.680093

# %% [markdown]
# # Conclusions:
# - As we can conclude that, The Model Generated by `RandomForestClassifier` Algorithem is the best `Model` for the given `Text Data - Sentiment Analysis project` compared to all other models.
# - The Evaluation matric - accuracy_score of `RandomForestClassifier` is high i.e., **`0.7921624046394624`**, Thus it is clear that RandomForestClassifier has the best performance of all models.
# - The Outliers are not removed, they are re-scaled ,the models had been generated and evaluation is done.
#
# - The model we generated is light for deployment and has medium level latency.
